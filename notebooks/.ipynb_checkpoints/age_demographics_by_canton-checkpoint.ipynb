# %%
import pandas
from functools import reduce

# %%
#Load age demographic data
canton_data_path = '../data/age_demographics/canton/'

# %%
#Process the files for each age category 
def read_data(category):
    df = pandas.read_excel(canton_data_path + 'population_age_%s.xlsx'%(category), skiprows =5, usecols = 'B:D', index_col = None, nrows = 26, 
            names = ['canton_name', 'num_%s'%(category), 'pc_%s'%category])
    return df

categories = ['0_19','20_39','40_64','65_plus','80_plus']

dfs = [read_data(x) for x in categories]

#merge dataframes into one
df = reduce(lambda x, y: pandas.merge(x, y, on = 'canton_name'), dfs)

# %%
df.head()
# Out:
#   canton_name  num_0_19    pc_0_19  num_20_39   pc_20_39  num_40_64  \
# 0      Zürich    300178  19.735984     436886  28.724207     525173
# 1        Bern    197081  19.042066     261422  25.258726     360990
# 2      Luzern     83363  20.354432     112493  27.466995     141633
# 3         Uri      7340  20.146570       8917  24.475064      12734
# 4      Schwyz     30986  19.467848      40186  25.248013      59761
#
#     pc_40_64  num_65_plus  pc_65_plus  num_80_plus  pc_80_plus
# 0  34.528866       258731   17.010943        73942    4.861509
# 1  34.879036       215484   20.820173        60710    5.865831
# 2  34.582000        72068   17.596574        20608    5.031778
# 3  34.951829         7442   20.426536         2010    5.516976
# 4  37.546571        28232   17.737568         7354    4.620363
