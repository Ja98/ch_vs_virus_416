# %%
import pandas 
import geopandas

# %%
#Load age demographic data
age_data_path = '../data/age_demographics/population_all_categories.xlsx'
municipal_age_df = pandas.read_excel(age_data_path)
municipal_age_df.head()
# Out:
#          municipality total_population    pc_0_19   pc_20_39   pc_40_64  \
# 0     Aeugst am Albis             1982  19.677094  19.172553  43.592331
# 1  Affoltern am Albis            12229  20.508627  28.121678  33.207948
# 2          Bonstetten             5548  23.666186  23.287671  37.022350
# 3     Hausen am Albis             3701  21.804918  19.535261  41.151040
# 4            Hedingen             3734  21.772898  22.013926  39.742903
#
#    pc_65_plus  pc_80_plus
# 0   17.558022    3.582240
# 1   18.161747    5.012675
# 2   16.023792    3.136265
# 3   17.508781    3.539584
# 4   16.470273    3.186931

# %%
#Load municipal boundaries map
municipal_boundaries_path = '../data/municipal_boundaries/swissBOUNDARIES3D_1_3_TLM_HOHEITSGEBIET.shx'
municipal_map = geopandas.read_file(municipal_boundaries_path)
municipal_map.head()
# Out:
#                                      UUID  DATUM_AEND  DATUM_ERST  ERSTELL_J  \
# 0  {D5A9677C-FE38-44F6-B0E8-3177F6252C81}  2017-12-04  2008-11-24       2000
# 1  {B55F9EAE-EB69-4468-A41C-7BB28A6699EE}  2017-12-04  2008-11-24       2006
# 2  {AB2BA4A5-EB8C-40C7-A259-271DAC93C767}  2017-12-04  2008-11-24       2000
# 3  {550D0610-1EE3-4748-8F29-88072753FFDC}  2017-12-04  2008-11-24       2000
# 4  {C9A12E0C-B661-4ED3-B5D2-C604EC55C7A6}  2016-12-09  2008-11-24       1900
#
#   ERSTELL_M  REVISION_J REVISION_M  GRUND_AEND   HERKUNFT  HERKUNFT_J  ...  \
# 0         1        2018          1  Verbessert  swisstopo        2018  ...
# 1         1        2018          1  Verbessert  swisstopo        2018  ...
# 2         1        2018          1  Verbessert  swisstopo        2018  ...
# 3         1        2018          1  Verbessert  swisstopo        2018  ...
# 4         1        2018          1  Verbessert  swisstopo        2017  ...
#
#     REVISION_Q            NAME  KANTONSNUM  ICC EINWOHNERZ BFS_NUMMER  \
# 0  2017_Aufbau           Scuol        18.0   CH     4638.0       3762
# 1  2017_Aufbau      Glarus Süd         8.0   CH     9575.0       1631
# 2  2017_Aufbau          Zernez        18.0   CH     1540.0       3746
# 3  2017_Aufbau          Surses        18.0   CH     2356.0       3543
# 4  2017_Aufbau  Lac Léman (VD)        22.0   CH        NaN       9758
#
#    GEM_TEIL GEM_FLAECH         SHN  \
# 0         0    43863.0  CH18433762
# 1         0    43003.0  CH08001631
# 2         0    34404.0  CH18433746
# 3         0    32377.0  CH18413543
# 4         1    29756.0  CH22009758
#
#                                             geometry
# 0  POLYGON Z ((826173.964 171304.890 2659.848, 82...
# 1  POLYGON Z ((714000.271 197614.962 2606.499, 71...
# 2  POLYGON Z ((802710.888 192062.325 3206.281, 80...
# 3  POLYGON Z ((759766.317 151299.638 3051.135, 75...
# 4  POLYGON Z ((549875.465 147188.823 372.146, 549...
#
# [5 rows x 24 columns]

# %%
#Load cantonal boundaries map 
cantonal_boundaries_path = '../data/cantonal_boundaries/swissBOUNDARIES3D_1_3_TLM_KANTONSGEBIET.shx'
cantonal_map = geopandas.read_file(cantonal_boundaries_path)
cantonal_map.head()
cantonal_map.dtypes
# Out:
# UUID            object
# DATUM_AEND      object
# DATUM_ERST      object
# ERSTELL_J        int64
# ERSTELL_M       object
# REVISION_J       int64
# REVISION_M      object
# GRUND_AEND      object
# HERKUNFT        object
# HERKUNFT_J       int64
# HERKUNFT_M      object
# OBJEKTART       object
# REVISION_Q      object
# ICC             object
# KANTONSNUM       int64
# SEE_FLAECH     float64
# KANTONSFLA     float64
# KT_TEIL         object
# NAME            object
# EINWOHNERZ     float64
# geometry      geometry
# dtype: object

# %%
#Plotting the cantonal population - this is just an example - need to link to the age demographics

cantonal_map.plot(column = 'EINWOHNERZ')

# %%
#Plotting the cantonal population - this is just an example - need to link to the age demographics

municipal_map.plot(column = 'EINWOHNERZ')
